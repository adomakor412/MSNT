# %% [markdown]
# Ronald Adomako
#
# CE 5338
#
# Hydrologic Engineering,
#
# Professor Martin Pierson
#
# HW 3, Sep. 14, 2022

# %%
from wand.image import Image as WImage
img = WImage(filename='5338+HW+3+Rational+Method.pdf')
img
# Out:
# <wand.image.Image: f94dab8 'PDF' (612x792)>

# %% [markdown]
# |PipeID # | Average Slope of Pipe, % | Length of Pipe , (ft) |
# | :---        |    :----:   |          ---: |
# |P1 |1.4 |170|
# |P2|0.5|160|
# |P3 |0.5 |125|
# |P4|0.5|140 |
# |P5 |0.3 |160|
# |P6|0.3|300|
# |P7| 0.2| 125|
# |P8|0.1|200|

# %% [markdown]
# ### Solution

# %% [markdown]
# ![Design_rain_storms.png](attachment:Design_rain_storms.png)

# %% [markdown]
# ![Precipitation_duration.png](attachment:Precipitation_duration.png)

# %% [markdown]
# ![Nk_factor_Kerby_Hathaway.png](attachment:Nk_factor_Kerby_Hathaway.png)

# %% [markdown]
# ![C_runoff_coeff.png](attachment:C_runoff_coeff.png)

# %% [markdown]
# ![Manning_roughness.png](attachment:Manning_roughness.png)

# %% [markdown]
# ### Design Peak for 10 year storm: $Q_{10}$

# %% [markdown]
# ![Solution.png](attachment:Solution.png)
